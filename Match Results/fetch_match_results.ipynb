# %%
# Import packages
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from datetime import datetime, timedelta
import os

# %%
# Set up webdriver configuration
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")
options.add_argument("--no-sandbox")
options.add_argument("--headless")
options.add_argument("--disable-gpu")
browser = webdriver.Chrome(options=options)

if not os.path.exists("webscraped_ncaa_games_history.parquet"):
    date = pd.to_datetime("1986-1-2").date() # Initialize with first date of data if no data is available
    columns = ["date", "home_team", "home_team_ranking", "home_team_score", "away_team", "away_team_ranking", "away_team_score", "gender"]
    df = pd.DataFrame(columns=columns)
    df.to_parquet("webscraped_ncaa_games_history.parquet")
else:
    date = pd.to_datetime(pd.read_parquet("webscraped_ncaa_games_history.parquet").date.max()).date()

browser.get(f"https://www.sports-reference.com/cbb/boxscores/index.cgi?month={date.month}&day={date.day}&year={date.year}") # Load last fetched date

#browser.find_element(By.XPATH, "/html/body/div[1]/div/div/div/div[2]/div/button[3]").click()

# %%
df
# Out:
#               date         home_team  home_team_ranking  home_team_score  \
# 0       1986-01-02        Holy Cross                NaN               77
# 1       1986-01-02  Central Michigan                NaN               63
# 2       1986-01-02          Hartford                NaN               54
# 3       1986-01-02           Cornell                NaN               78
# 4       1986-01-02            Oregon                NaN               65
# ...            ...               ...                ...              ...
# 314686  2024-11-17      Sacred Heart                NaN               70
# 314687  2024-11-17          Cal Poly                NaN               82
# 314688  2024-11-17        California                NaN               71
# 314689  2024-11-17       Weber State                NaN               68
# 314690  2024-11-17      UMass-Lowell                NaN               69
#
#                  away_team  away_team_ranking  away_team_score gender
# 0                     Yale                NaN               86      m
# 1         Western Michigan                NaN               74      m
# 2                 Virginia                NaN               73      m
# 3                    Utica                NaN               88      m
# 4                     UCLA                NaN               71      m
# ...                    ...                ...              ...    ...
# 314686               Brown                NaN               89      m
# 314687  Eastern Washington                NaN               78      m
# 314688                 USC                NaN               66      m
# 314689              Hawaii                NaN               73      m
# 314690          Washington                NaN               74      m
#
# [314691 rows x 8 columns]

# %%
finished_scraping = False # Set up while loop

df = pd.read_parquet("webscraped_ncaa_games_history.parquet") # Load already fetched database

while not finished_scraping:
    date = (date + timedelta(days = 1)) # Fetch next date

    if date.month == 5 and date.day == 1: date = date.replace(month=11, day=1) # If the date is May 1st, jump to November 1st of the same year
    
    if date > datetime.now().date(): # If the date is in the future, quit the script
        finished_scraping = True 
        browser.quit()
        continue

    browser.get(f"https://www.sports-reference.com/cbb/boxscores/index.cgi?month={date.month}&day={date.day}&year={date.year}")
    time.sleep(1)

    elements = browser.find_elements(By.CLASS_NAME, "game_summary") # Get all match result elements

    if date.day in [1, 11, 21]: # Periodically save data
        df.to_parquet("webscraped_ncaa_games_history.parquet")
        print(f"Saved data on {date}.")

    if len(elements) > 0: # If there are any match results on the page
        for element in elements:
            try:
                if "hidden" not in element.get_attribute("class").split():
                    home_team = element.find_elements(By.CSS_SELECTOR, "td")[0].text.split(" (")[0]
                    home_team_score = int(element.find_elements(By.CSS_SELECTOR, "td")[1].text)
                    away_team = element.find_elements(By.CSS_SELECTOR, "td")[3].text.split(" (")[0]
                    away_team_score = int(element.find_elements(By.CSS_SELECTOR, "td")[4].text)
                    gender = element.get_attribute("class")[-1:]
                    try: 
                        home_team_ranking = int(element.find_elements(By.CSS_SELECTOR, "td")[0].text.split(" (")[1].replace(") ", ""))
                        away_team_ranking = int(element.find_elements(By.CSS_SELECTOR, "td")[3].text.split(" (")[1].replace(") ", ""))
                    except:
                        home_team_ranking = np.nan
                        away_team_ranking = np.nan

                    df.loc[df.shape[0]] = [date, home_team, home_team_ranking, home_team_score, away_team, away_team_ranking, away_team_score, gender] # Insert new row into the bottom of the dataframe

            except Exception as e: # Simple error handling, often parsing of integers fails due to empty strings when elements are found but are empty on days with no matches. This is a crude but working fix.
                pass
        print(f"Finished collecting data for {date}!")

df.to_parquet("webscraped_ncaa_games_history.parquet") # Save data to parquet file once finished
print(f"Saved data on {date}.")
# Out:
# Saved data on 2023-11-11.
# Finished collecting data for 2023-11-11!
# Finished collecting data for 2023-11-12!
# Finished collecting data for 2023-11-13!
# Finished collecting data for 2023-11-14!
# Finished collecting data for 2023-11-15!
# Finished collecting data for 2023-11-16!
# Finished collecting data for 2023-11-17!
# Finished collecting data for 2023-11-18!
# Finished collecting data for 2023-11-19!
# Finished collecting data for 2023-11-20!
# Saved data on 2023-11-21.
# Finished collecting data for 2023-11-21!
# Finished collecting data for 2023-11-22!
# Finished collecting data for 2023-11-23!
# Finished collecting data for 2023-11-24!
# Finished collecting data for 2023-11-25!
# Finished collecting data for 2023-11-26!
# Finished collecting data for 2023-11-27!
# Finished collecting data for 2023-11-28!
# Finished collecting data for 2023-11-29!
# Finished collecting data for 2023-11-30!
# Saved data on 2023-12-01.
# Finished collecting data for 2023-12-01!
# Finished collecting data for 2023-12-02!
# Finished collecting data for 2023-12-03!
# Finished collecting data for 2023-12-04!
# Finished collecting data for 2023-12-05!
# Finished collecting data for 2023-12-06!
# Finished collecting data for 2023-12-07!
# Finished collecting data for 2023-12-08!
# Finished collecting data for 2023-12-09!
# Finished collecting data for 2023-12-10!
# Saved data on 2023-12-11.
# Finished collecting data for 2023-12-11!
# Finished collecting data for 2023-12-12!
# Finished collecting data for 2023-12-13!
# Finished collecting data for 2023-12-14!
# Finished collecting data for 2023-12-15!
# Finished collecting data for 2023-12-16!
# Finished collecting data for 2023-12-17!
# Finished collecting data for 2023-12-18!
# Finished collecting data for 2023-12-19!
# Finished collecting data for 2023-12-20!
# Saved data on 2023-12-21.
# Finished collecting data for 2023-12-21!
# Finished collecting data for 2023-12-22!
# Finished collecting data for 2023-12-23!
# Finished collecting data for 2023-12-24!
# Finished collecting data for 2023-12-25!
# Finished collecting data for 2023-12-26!
# Finished collecting data for 2023-12-27!
# Finished collecting data for 2023-12-28!
# Finished collecting data for 2023-12-29!
# Finished collecting data for 2023-12-30!
# Finished collecting data for 2023-12-31!
# Saved data on 2024-01-01.
# Finished collecting data for 2024-01-01!
# Finished collecting data for 2024-01-02!
# Finished collecting data for 2024-01-03!
# Finished collecting data for 2024-01-04!
# Finished collecting data for 2024-01-05!
# Finished collecting data for 2024-01-06!
# Finished collecting data for 2024-01-07!
# Finished collecting data for 2024-01-08!
# Finished collecting data for 2024-01-09!
# Finished collecting data for 2024-01-10!
# Saved data on 2024-01-11.
# Finished collecting data for 2024-01-11!
# Finished collecting data for 2024-01-12!
# Finished collecting data for 2024-01-13!
# Finished collecting data for 2024-01-14!
# Finished collecting data for 2024-01-15!
# Finished collecting data for 2024-01-16!
# Finished collecting data for 2024-01-17!
# Finished collecting data for 2024-01-18!
# Finished collecting data for 2024-01-19!
# Finished collecting data for 2024-01-20!
# Saved data on 2024-01-21.
# Finished collecting data for 2024-01-21!
# Finished collecting data for 2024-01-22!
# Finished collecting data for 2024-01-23!
# Finished collecting data for 2024-01-24!
# Finished collecting data for 2024-01-25!
# Finished collecting data for 2024-01-26!
# Finished collecting data for 2024-01-27!
# Finished collecting data for 2024-01-28!
# Finished collecting data for 2024-01-29!
# Finished collecting data for 2024-01-30!
# Finished collecting data for 2024-01-31!
# Saved data on 2024-02-01.
# Finished collecting data for 2024-02-01!
# Finished collecting data for 2024-02-02!
# Finished collecting data for 2024-02-03!
# Finished collecting data for 2024-02-04!
# Finished collecting data for 2024-02-05!
# Finished collecting data for 2024-02-06!
# Finished collecting data for 2024-02-07!
# Finished collecting data for 2024-02-08!
# Finished collecting data for 2024-02-09!
# Finished collecting data for 2024-02-10!
# Saved data on 2024-02-11.
# Finished collecting data for 2024-02-11!
# Finished collecting data for 2024-02-12!
# Finished collecting data for 2024-02-13!
# Finished collecting data for 2024-02-14!
# Finished collecting data for 2024-02-15!
# Finished collecting data for 2024-02-16!
# Finished collecting data for 2024-02-17!
# Finished collecting data for 2024-02-18!
# Finished collecting data for 2024-02-19!
# Finished collecting data for 2024-02-20!
# Saved data on 2024-02-21.
# Finished collecting data for 2024-02-21!
# Finished collecting data for 2024-02-22!
# Finished collecting data for 2024-02-23!
# Finished collecting data for 2024-02-24!
# Finished collecting data for 2024-02-25!
# Finished collecting data for 2024-02-26!
# Finished collecting data for 2024-02-27!
# Finished collecting data for 2024-02-28!
# Finished collecting data for 2024-02-29!
# Saved data on 2024-03-01.
# Finished collecting data for 2024-03-01!
# Finished collecting data for 2024-03-02!
# Finished collecting data for 2024-03-03!
# Finished collecting data for 2024-03-04!
# Finished collecting data for 2024-03-05!
# Finished collecting data for 2024-03-06!
# Finished collecting data for 2024-03-07!
# Finished collecting data for 2024-03-08!
# Finished collecting data for 2024-03-09!
# Finished collecting data for 2024-03-10!
# Saved data on 2024-03-11.
# Finished collecting data for 2024-03-11!
# Finished collecting data for 2024-03-12!
# Finished collecting data for 2024-03-13!
# Finished collecting data for 2024-03-14!
# Finished collecting data for 2024-03-15!
# Finished collecting data for 2024-03-16!
# Finished collecting data for 2024-03-17!
# Finished collecting data for 2024-03-18!
# Finished collecting data for 2024-03-19!
# Finished collecting data for 2024-03-20!
# Saved data on 2024-03-21.
# Finished collecting data for 2024-03-21!
# Finished collecting data for 2024-03-22!
# Finished collecting data for 2024-03-23!
# Finished collecting data for 2024-03-24!
# Finished collecting data for 2024-03-25!
# Finished collecting data for 2024-03-26!
# Finished collecting data for 2024-03-27!
# Finished collecting data for 2024-03-28!
# Finished collecting data for 2024-03-29!
# Finished collecting data for 2024-03-30!
# Finished collecting data for 2024-03-31!
# Saved data on 2024-04-01.
# Finished collecting data for 2024-04-01!
# Finished collecting data for 2024-04-02!
# Finished collecting data for 2024-04-03!
# Finished collecting data for 2024-04-04!
# Finished collecting data for 2024-04-05!
# Finished collecting data for 2024-04-06!
# Finished collecting data for 2024-04-07!
# Finished collecting data for 2024-04-08!
# Finished collecting data for 2024-04-09!
# Finished collecting data for 2024-04-10!
# Saved data on 2024-04-11.
# Finished collecting data for 2024-04-11!
# Finished collecting data for 2024-04-12!
# Finished collecting data for 2024-04-13!
# Finished collecting data for 2024-04-14!
# Finished collecting data for 2024-04-15!
# Finished collecting data for 2024-04-16!
# Finished collecting data for 2024-04-17!
# Finished collecting data for 2024-04-18!
# Finished collecting data for 2024-04-19!
# Finished collecting data for 2024-04-20!
# Saved data on 2024-04-21.
# Finished collecting data for 2024-04-21!
# Finished collecting data for 2024-04-22!
# Finished collecting data for 2024-04-23!
# Finished collecting data for 2024-04-24!
# Finished collecting data for 2024-04-25!
# Finished collecting data for 2024-04-26!
# Finished collecting data for 2024-04-27!
# Finished collecting data for 2024-04-28!
# Finished collecting data for 2024-04-29!
# Finished collecting data for 2024-04-30!
# Saved data on 2024-11-01.
# Finished collecting data for 2024-11-01!
# Finished collecting data for 2024-11-02!
# Finished collecting data for 2024-11-03!
# Finished collecting data for 2024-11-04!
# Finished collecting data for 2024-11-05!
# Finished collecting data for 2024-11-06!
# Finished collecting data for 2024-11-07!
# Finished collecting data for 2024-11-08!
# Finished collecting data for 2024-11-09!
# Finished collecting data for 2024-11-10!
# Saved data on 2024-11-11.
# Finished collecting data for 2024-11-11!
# Finished collecting data for 2024-11-12!
# Finished collecting data for 2024-11-13!
# Finished collecting data for 2024-11-14!
# Finished collecting data for 2024-11-15!
# Finished collecting data for 2024-11-16!
# Finished collecting data for 2024-11-17!
# Finished collecting data for 2024-11-18!
